# %%
# WeatherPy

# Note

#  Instructions have been included for each segment. 
#  You do not have to follow them exactly, 
#        but they are included to help you think through the steps.

#  Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)  

# Generate Cities List
#      List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination using citipy
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
print (f"Number of Cities accumulated: {len(cities)}") 
cities
# Out:
# Number of Cities accumulated: 618
# ['west plains',
#  'tabukiniberu',
#  'bengkulu',
#  'illoqqortoormiut',
#  'saldanha',
#  'yellowknife',
#  'arraial do cabo',
#  'hilo',
#  'manaquiri',
#  'cherskiy',
#  'mataura',
#  'olga',
#  'iqaluit',
#  'sitka',
#  'hobart',
#  'geraldton',
#  'bluff',
#  'mjolby',
#  'carnarvon',
#  'puerto ayora',
#  'huarmey',
#  'faanui',
#  'preston',
#  'rikitea',
#  'vaini',
#  'tasiilaq',
#  'diego de almagro',
#  'tilichiki',
#  'ternate',
#  'shingu',
#  'lagoa',
#  'luanda',
#  'mount isa',
#  'varhaug',
#  'grand river south east',
#  'clyde river',
#  'port hedland',
#  'evensk',
#  'cape town',
#  'bredasdorp',
#  'gamboma',
#  'denpasar',
#  'albany',
#  'aklavik',
#  'bambous virieux',
#  'saint-philippe',
#  'thompson',
#  'hermanus',
#  'korla',
#  'port lincoln',
#  'taolanaro',
#  'odweyne',
#  'ahipara',
#  'jamestown',
#  'nizhneyansk',
#  'mys shmidta',
#  'adrar',
#  'busselton',
#  'hamilton',
#  'forlimpopoli',
#  'salalah',
#  'kaitangata',
#  'ambilobe',
#  'balakovo',
#  'gimli',
#  'viedma',
#  'coquimbo',
#  'butaritari',
#  'ushuaia',
#  'nastola',
#  'nelson bay',
#  'qarqin',
#  'xichang',
#  'vaitupu',
#  'mudgee',
#  'kapaa',
#  'mehamn',
#  'aykhal',
#  'khatanga',
#  'san policarpo',
#  'tuatapere',
#  'port-gentil',
#  'spornoye',
#  'sinnamary',
#  'klaksvik',
#  'barrow',
#  'emerald',
#  'mabaruma',
#  'fort saint james',
#  'the valley',
#  'matamoros',
#  'nome',
#  'marcona',
#  'svobodnyy',
#  'georgetown',
#  'cayenne',
#  'upernavik',
#  'vestmannaeyjar',
#  'faya',
#  'victoria',
#  'zyryanka',
#  'narsaq',
#  'balassagyarmat',
#  'lavrentiya',
#  'provideniya',
#  'yarada',
#  'tuktoyaktuk',
#  'muswellbrook',
#  'dikson',
#  'pevek',
#  'mar del plata',
#  'dongsheng',
#  'torbay',
#  'dolores',
#  'port alfred',
#  'guerrero negro',
#  'poum',
#  'payo',
#  'vila',
#  'punta arenas',
#  'hami',
#  'horsham',
#  'jiayuguan',
#  'srandakan',
#  'kijang',
#  'san rafael',
#  'saleaula',
#  'kumluca',
#  'atuona',
#  'maniitsoq',
#  'westport',
#  'sur',
#  'avarua',
#  'hithadhoo',
#  'quimper',
#  'fremont',
#  'maceio',
#  'belgrade',
#  'pingxiang',
#  'egvekinot',
#  'manokwari',
#  'loum',
#  'hoover',
#  'chokurdakh',
#  'macau',
#  'mitla',
#  'longyearbyen',
#  'launceston',
#  'ambodifototra',
#  'orsha',
#  'veraval',
#  'abu dhabi',
#  'udachnyy',
#  'manzhouli',
#  'attawapiskat',
#  'port elizabeth',
#  'kodiak',
#  'watrous',
#  'smolensk',
#  'sentyabrskiy',
#  'nikolskoye',
#  'mokrous',
#  'xiaoweizhai',
#  'balykshi',
#  'cotonou',
#  'rio linda',
#  'mahebourg',
#  'ribeira grande',
#  'ust-tsilma',
#  'bambanglipuro',
#  'lusambo',
#  'benjamin constant',
#  'suntar',
#  'lompoc',
#  'talas',
#  'olafsvik',
#  'jalu',
#  'dalvik',
#  'ilulissat',
#  'taihe',
#  'souillac',
#  'nauta',
#  'vanimo',
#  'san patricio',
#  'qaanaaq',
#  'timmins',
#  'esperance',
#  'port hardy',
#  'rawannawi',
#  'flin flon',
#  'skjervoy',
#  'jahrom',
#  'hasaki',
#  'snasa',
#  'ponta do sol',
#  'galesong',
#  'los llanos de aridane',
#  'gao',
#  'saint george',
#  'makakilo city',
#  'varniai',
#  'gamba',
#  'praia',
#  'dingle',
#  'sorland',
#  'kyaikto',
#  'ituni',
#  'vila velha',
#  'castro',
#  'san cristobal',
#  'puerto escondido',
#  'kloulklubed',
#  'harper',
#  'nioro',
#  'port macquarie',
#  'dodola',
#  'chapais',
#  'saint-joseph',
#  'nibbar',
#  'vardo',
#  'eureka',
#  'marquette',
#  'amderma',
#  'gorno-chuyskiy',
#  'phumi samraong',
#  'umm kaddadah',
#  'dawson creek',
#  'khandyga',
#  'oum hadjer',
#  'damietta',
#  'conceicao do araguaia',
#  'araouane',
#  'isangel',
#  'petit goave',
#  'mogadishu',
#  'arica',
#  'pochutla',
#  'rosarno',
#  'sinjar',
#  'marystown',
#  'razvilnoye',
#  'new norfolk',
#  'kavaratti',
#  'lamu',
#  'norman wells',
#  'muros',
#  'scarborough',
#  'chandbali',
#  'manaus',
#  'goderich',
#  'alice springs',
#  'sinegorskiy',
#  'kieta',
#  'yumen',
#  'alto piquiri',
#  'santa barbara',
#  'kovdor',
#  'nuuk',
#  'kafyr-kumukh',
#  'playa vicente',
#  'bilibino',
#  'usinsk',
#  'hannibal',
#  'yar-sale',
#  'rzhev',
#  'rongcheng',
#  'shalakusha',
#  'sambava',
#  'yamada',
#  'ampanihy',
#  'lata',
#  'bonavista',
#  'severo-kurilsk',
#  'kautokeino',
#  'belushya guba',
#  'irbil',
#  'progreso',
#  'semey',
#  'ruzomberok',
#  'cidreira',
#  'tommot',
#  'barentsburg',
#  'kuhdasht',
#  'payakumbuh',
#  'hovd',
#  'mizdah',
#  'kholtoson',
#  'namatanai',
#  'moreno',
#  'katsuura',
#  'wilmington',
#  'touros',
#  'constitucion',
#  'maholi',
#  'abnub',
#  'aginskoye',
#  'shache',
#  'atasu',
#  'tsihombe',
#  'gilgit',
#  'deputatskiy',
#  'kayankulam',
#  'roebourne',
#  'batemans bay',
#  'zapolyarnyy',
#  'kiunga',
#  'aloleng',
#  'coihaique',
#  'sulphur springs',
#  'ikalamavony',
#  'pendleton',
#  'lebu',
#  'general roca',
#  'malatya',
#  'vetlanda',
#  'muroto',
#  'cocorit',
#  'chantilly',
#  'kaeo',
#  'luderitz',
#  'moshenskoye',
#  'rockford',
#  'palu',
#  'sao joao da barra',
#  'tornio',
#  'cabo san lucas',
#  'umea',
#  'aflu',
#  'kadykchan',
#  'ndjole',
#  'mnogovershinnyy',
#  'kenai',
#  'kigoma',
#  'temaraia',
#  'richards bay',
#  'saint-georges',
#  'sargatskoye',
#  'komsomolskiy',
#  'wellington',
#  'penzance',
#  'roald',
#  'leningradskiy',
#  'fortuna',
#  'parambu',
#  'east london',
#  'hokitika',
#  'saint stephen',
#  'hemnesberget',
#  'henties bay',
#  'pisco',
#  'hambantota',
#  'viligili',
#  'durham',
#  'santa rosa',
#  'aswan',
#  'shimoda',
#  'bhairab bazar',
#  'petropavlovsk-kamchatskiy',
#  'verkhoyansk',
#  'new richmond',
#  'srednekolymsk',
#  'corner brook',
#  'samastipur',
#  'kondol',
#  'ciudad real',
#  'merritt island',
#  'kirakira',
#  'yirol',
#  'husavik',
#  'asyut',
#  'mareeba',
#  'iquira',
#  'gandajika',
#  'vysokogornyy',
#  'rudnogorsk',
#  'jumla',
#  'kiruna',
#  'ayagoz',
#  'lufilufi',
#  'arroyo',
#  'tiksi',
#  'huejucar',
#  'taksimo',
#  'tomatlan',
#  'pagudpud',
#  'karaul',
#  'steinbach',
#  'lucapa',
#  'neiafu',
#  'ancud',
#  'teguldet',
#  'dayong',
#  'port maria',
#  'sao filipe',
#  'chachapoyas',
#  'trairi',
#  'dinghai',
#  'kulhudhuffushi',
#  'bethel',
#  'bargal',
#  'walvis bay',
#  'mayo',
#  'kamenskoye',
#  'vista hermosa',
#  'khor',
#  'gladstone',
#  'staryy nadym',
#  'santa fe',
#  'berea',
#  'lawrence',
#  'chicama',
#  'lensk',
#  'vao',
#  'bandarbeyla',
#  'chuy',
#  'chenzhou',
#  'bontang',
#  'saint-pierre',
#  'aden',
#  'jingdezhen',
#  'port augusta',
#  'hunza',
#  'juegang',
#  'palkaka',
#  'back mountain',
#  'ghanzi',
#  'longlac',
#  'tateyama',
#  'airai',
#  'ozgon',
#  'ranong',
#  'puerto madryn',
#  'vanavara',
#  'arys',
#  'areosa',
#  'kavieng',
#  'oranjemund',
#  'katsiveli',
#  'pacific grove',
#  'mergui',
#  'samusu',
#  'stuttgart',
#  'birao',
#  'bridlington',
#  'labuhan',
#  'qaqortoq',
#  'wrexham',
#  'lundazi',
#  'barawe',
#  'malkangiri',
#  'wanning',
#  'high rock',
#  'dudinka',
#  'cap malheureux',
#  'nanortalik',
#  'mana',
#  'elk city',
#  'honiara',
#  'vila franca do campo',
#  'pitanga',
#  'la merced',
#  'gigmoto',
#  'champerico',
#  'san quintin',
#  'makat',
#  'valverde del camino',
#  'mocambique',
#  'samarai',
#  'wajima',
#  'takoradi',
#  'broome',
#  'hofn',
#  'issoudun',
#  'necochea',
#  'santiago del estero',
#  'tokur',
#  'acari',
#  'lolua',
#  'kizukuri',
#  'doume',
#  'ostrovnoy',
#  'ondjiva',
#  'half moon bay',
#  'santiago',
#  'fairbanks',
#  'kahului',
#  'ust-barguzin',
#  'goiatuba',
#  'yangambi',
#  'grand centre',
#  'naze',
#  'waingapu',
#  'madras',
#  'westpunt',
#  'micheweni',
#  'abulug',
#  'miranda',
#  'lenger',
#  'iquitos',
#  'salinopolis',
#  'tanabe',
#  'talnakh',
#  'springville',
#  'vrangel',
#  'zharkent',
#  'sabya',
#  'dzhebariki-khaya',
#  'ereymentau',
#  'tobol',
#  'mendahara',
#  'durres',
#  'sehithwa',
#  'show low',
#  'codrington',
#  'najran',
#  'sistranda',
#  'bur gabo',
#  'okato',
#  'funadhoo',
#  'ouallam',
#  'teguise',
#  'tahta',
#  'oda',
#  'rawson',
#  'valparaiso',
#  'zeya',
#  'isiro',
#  'kruisfontein',
#  'port blair',
#  'ruteng',
#  'minna',
#  'chake chake',
#  'biltine',
#  'mitchell',
#  'iskateley',
#  'yining',
#  'magistralnyy',
#  'puerto baquerizo moreno',
#  'lorengau',
#  'te anau',
#  'paamiut',
#  'palaikastron',
#  'mamlyutka',
#  'nyurba',
#  'sola',
#  'tasbuget',
#  'nouadhibou',
#  'tombouctou',
#  'farah',
#  'middelburg',
#  'goundam',
#  'kawalu',
#  'manzil tamim',
#  'salym',
#  'sibolga',
#  'layou',
#  'caucaia',
#  'anloga',
#  'gat',
#  'college',
#  'montevideo',
#  'batagay-alyta',
#  'san jose',
#  'coari',
#  'springbok',
#  'dwarka',
#  'rochester',
#  'charters towers',
#  'nishihara',
#  'constantine',
#  'saskylakh',
#  'ugoofaaru',
#  'cockburn harbour',
#  'pietarsaari',
#  'arsk',
#  'namibe',
#  'llangefni',
#  'kaseda',
#  'gombong',
#  'villanueva',
#  'singaparna',
#  'tavda',
#  'lithgow',
#  'bayan',
#  'roma',
#  'banda aceh',
#  'mitsamiouli',
#  'padang',
#  'snezhnogorsk',
#  'nantucket',
#  'havoysund',
#  'china',
#  'mildura',
#  'bafq',
#  'vryheid',
#  'yuli',
#  'alirajpur',
#  'piopio',
#  'sorokino',
#  'tessalit',
#  'kununurra',
#  'bhag',
#  'taoudenni',
#  'brownsville',
#  'tawang',
#  'malwan',
#  'sumbe',
#  'hecun',
#  'tumannyy',
#  'farafangana',
#  'chabahar',
#  'burnie',
#  'sayyan',
#  'lozovo',
#  'barbar',
#  'vaasa',
#  'manzil jamil',
#  'nakamura']

# %%
#  Perform API Calls
#      Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"                                      # alternative is "metric"

#      Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#      Set up lists to hold reponse info
CityName = []
CityID = []
Cloudiness = []
CountryCd = []
Date = []
Humidity = []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []

#       Perform a weather check on each city using a series of successive API calls.

# Loop through the list of cities and perform a request for data on each
# Model for weather:
#   Current weather object for Paris: 
#        {'coord': {'lon': 2.35, 'lat': 48.86}, 
#         'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 
#         'base': 'stations', 
#         'main': {'temp': 1.14, 'pressure': 1021, 'humidity': 80, 'temp_min': 1, 'temp_max': 2}, 
#         'visibility': 5000, 
#         'wind': {'speed': 3.6, 'deg': 20}, 
#         'clouds': {'all': 0}, 
#         'dt': 1519248600, 
#         'sys': {'type': 1, 'id': 5610, 'message': 0.0054, 'country': 'FR', 'sunrise': 1519195590, 'sunset': 1519233747}, 
#         'id': 2988507, 
#         'name': 'Paris', 
#         'cod': 200}.

for city in cities:
    response = requests.get(query_url + city).json()
#    pprint (response)  
    
    # Try to grab City info available in the Weather API
    try:
        CityName.append(response['name'])
        CityID.append(response['id'])
        Cloudiness.append(response['clouds']['all'])   
        CountryCd.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        MaxTemp.append(response['main']['temp_max'])
        WindSpeed.append(response['wind']['speed'])

        #       Include a print log of each city as it's being processed (with the city number and city name).
        print (f"City: {response['name']} and CityID: {response['id']}")
    
    # Handle exceptions for a City that is not available in the Weather API
    except:
        print (f"------City: {city} is not found in the Weather API - return code: {response['cod']}")
        pass
# Out:
# City: West Plains and CityID: 4414200
# ------City: tabukiniberu is not found in the Weather API - return code: 404
# City: Bengkulu and CityID: 1649150
# ------City: illoqqortoormiut is not found in the Weather API - return code: 404
# City: Saldanha and CityID: 3361934
# City: Yellowknife and CityID: 6185377
# City: Arraial do Cabo and CityID: 3471451
# City: Hilo and CityID: 5855927
# City: Manaquiri and CityID: 3663524
# City: Cherskiy and CityID: 2126199
# City: Mataura and CityID: 6201424
# City: Ol'ga and CityID: 2018553
# City: Iqaluit and CityID: 5983720
# City: Sitka and CityID: 5557293
# City: Hobart and CityID: 2163355
# City: Geraldton and CityID: 2070998
# City: Bluff and CityID: 2206939
# City: Mjölby and CityID: 2691743
# City: Carnarvon and CityID: 2074865
# City: Puerto Ayora and CityID: 3652764
# City: Huarmey and CityID: 3939168
# City: Faanui and CityID: 4034551
# City: Preston and CityID: 2639912
# City: Rikitea and CityID: 4030556
# City: Vaini and CityID: 4032243
# City: Tasiilaq and CityID: 3424607
# City: Diego de Almagro and CityID: 3892454
# City: Tilichiki and CityID: 2120591
# City: Ternate and CityID: 1624041
# City: Shingū and CityID: 1847947
# City: Lagoa and CityID: 3372964
# City: Luanda and CityID: 2240449
# City: Mount Isa and CityID: 2065594
# City: Varhaug and CityID: 3132644
# ------City: grand river south east is not found in the Weather API - return code: 404
# City: Clyde River and CityID: 5924351
# City: Port Hedland and CityID: 2063042
# City: Evensk and CityID: 2125693
# City: Cape Town and CityID: 3369157
# City: Bredasdorp and CityID: 1015776
# City: Gamboma and CityID: 2259947
# City: Bāfq and CityID: 142255
# City: Vryheid and CityID: 942470
# City: Yuli and CityID: 2317982
# City: Alirajpur and CityID: 1258815
# City: Piopio and CityID: 2184564
# City: Sorokino and CityID: 1491378
# City: Tessalit and CityID: 2449893
# City: Kununurra and CityID: 2068110
# City: Bhag and CityID: 1182872
# City: Taoudenni and CityID: 2450173
# City: Brownsville and CityID: 4676740
# City: Tawang Town and CityID: 1254832
# ------City: malwan is not found in the Weather API - return code: 404
# City: Sumbe and CityID: 3346015
# City: Hecun and CityID: 1808747
# ------City: tumannyy is not found in the Weather API - return code: 404
# City: Farafangana and CityID: 1065158
# City: Chabahar and CityID: 1161724
# City: Burnie and CityID: 2173125
# City: Sayyan and CityID: 70979
# City: Lozovo and CityID: 790848
# ------City: barbar is not found in the Weather API - return code: 404
# City: Vaasa and CityID: 632978
# ------City: manzil jamil is not found in the Weather API - return code: 404
# City: Nakamura and CityID: 1855891

# %%
#-----------------------------
#Data Retrieval Complete      
#-----------------------------
# Convert Raw Data to DataFrame
weather_dict = {
    "CityName": CityName,
    "CityID": CityID,
    "Cloudiness": Cloudiness,
    "CountryCd": CountryCd,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "MaxTemp": MaxTemp,
    "WindSpeed": WindSpeed
    }
# create a data frame from City,CityID,Cloudiness,CountryCd,Date,Humidity,lat,Lng,MaxTemp,WindSpeed
weather_data = pd.DataFrame(weather_dict)

# %%
#Export the city data into a .csv.   "../output_data/cities.csv"
# Save the updated dataframe as a csv
weather_data.to_csv("output_data/cities.csv", encoding="utf-8", index=False)

#Display the DataFrame        ---How to format date (unix dt) https://momentjs.com/---
weather_data.head()
# Out:
#           CityName   CityID  Cloudiness CountryCd        Date  Humidity  \
# 0      West Plains  4414200           1        US  1583562113        61
# 1         Bengkulu  1649150          46        ID  1583562113        52
# 2         Saldanha  3361934           0        ZA  1583562113        88
# 3      Yellowknife  6185377           5        CA  1583562114        67
# 4  Arraial do Cabo  3471451          94        BR  1583562114        80
#
#      Lat     Lng  MaxTemp  WindSpeed
# 0  36.73  -91.85    42.80       4.21
# 1  -3.80  102.27    90.75       7.58
# 2 -33.01   17.94    66.20       2.24
# 3  62.46 -114.35   -22.00       5.82
# 4 -22.97  -42.03    74.39      13.65

# %%
# Plotting the Data

#      Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#      Save the plotted figures as .pngs.

#      After each plot add a sentence or too explaining what the code is and analyzing. 
#      Your first objective is to build a series of scatter plots to showcase the following relationships:

# %%
# * Temperature (F) vs. Latitude
plt.scatter(weather_data["MaxTemp"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Max Temperature vs Latitude for World Cities Mar/2020")
plt.xlabel("Temperature (F)")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("MaxTempVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The further a world city is located from the equator, as defined by their latitude (both north & south / positive & negative) 
# their maximum temperature exhibits colder temperatures, and the closer to the equator, the warmer the temperatures.

# %%
# * Humidity (%) vs. Latitude
plt.scatter(weather_data["Humidity"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Humidity vs Latitude for World Cities Mar/2020")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# Humidity has the greatest variance in the Middle latitudes. Humidity at the highest levels 
# is concentrated from south 40 degrees to north 75 degrees.

# %%
# * Cloudiness (%) vs. Latitude
plt.scatter(weather_data["Cloudiness"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Cloudiness vs Latitude for World Cities Mar/2020")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The relative cloudiness seems disbursed across the earth.

# %%
# * Wind Speed (mph) vs. Latitude
plt.scatter(weather_data["WindSpeed"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Wind Speed vs Latitude for World Cities Mar/2020")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The greatest wind speed variance occurs in the middle latitudes (25-65mph in the North and 20-45mph in the South) ).

# %%
# Your next objective is to run linear regression on each relationship, only this time separating them into 
#                      Northern Hemisphere (greater than or equal to 0 degrees latitude)        
#                      and Southern Hemisphere (less than 0 degrees latitude):

# %%
#* Northern Hemisphere - Temperature (F) vs. Latitude
#* Southern Hemisphere - Temperature (F) vs. Latitude

# %%
#* Northern Hemisphere - Humidity (%) vs. Latitude
#* Southern Hemisphere - Humidity (%) vs. Latitude

# %%
#* Northern Hemisphere - Cloudiness (%) vs. Latitude
#* Southern Hemisphere - Cloudiness (%) vs. Latitude

# %%
#* Northern Hemisphere - Wind Speed (mph) vs. Latitude
#* Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
# After each pair of plots explain what the linear regression is modelling such as any relationships you notice 
# and any other analysis you may have.

# %%
 Linear Regression
    
 In [108]:  # OPTIONAL: Create a function to create Linear Regression plots
    
  In [78]:  # Create Northern and Southern Hemisphere DataFrames
  Northern Hemisphere - Max Temp vs. Latitude Linear Regression
 In [109]:    Out [109]:  The r-squared is: -0.8151657406810827
  Southern Hemisphere - Max Temp vs. Latitude Linear Regression
 In [110]:    Out [110]:  The r-squared is: 0.760263355051646
  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
 In [111]:    Out [111]:  The r-squared is: 0.10358336015746494
  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
 In [112]:    Out [112]:  The r-squared is: 0.14689473425583055
  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
 In [115]:    Out [115]:  The r-squared is: -0.08733547918934018
  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
 In [114]:    Out [114]:  The r-squared is: 0.21881426893991618
  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
 In [117]:    Out [117]:  The r-squared is: 0.1071382774388479
  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
 In [116]:    Out [116]:  The r-squared is: -0.322483077139538

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
