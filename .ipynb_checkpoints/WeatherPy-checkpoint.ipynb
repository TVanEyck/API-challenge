# %%
# WeatherPy

# Note

#  Instructions have been included for each segment. 
#  You do not have to follow them exactly, 
#        but they are included to help you think through the steps.

#  Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)  

# Generate Cities List
#      List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination using citipy
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
print (f"Number of Cities accumulated: {len(cities)}") 
cities
# Out:
# Number of Cities accumulated: 618
# ['kapaa',
#  'busselton',
#  'atuona',
#  'sentyabrskiy',
#  'nizhneyansk',
#  'mercedes',
#  'pozo colorado',
#  'albany',
#  'kropotkin',
#  'hobart',
#  'lebu',
#  'taolanaro',
#  'kodiak',
#  'san carlos del zulia',
#  'carnarvon',
#  'dingle',
#  'punta arenas',
#  'jamestown',
#  'pouembout',
#  'ganzhou',
#  'laguna',
#  'sitka',
#  'cockburn town',
#  'qaanaaq',
#  'belushya guba',
#  'port elizabeth',
#  'salalah',
#  'kaitangata',
#  'berlevag',
#  'mataura',
#  'husavik',
#  'fortuna',
#  'tuatapere',
#  'avarua',
#  'vila franca do campo',
#  'rikitea',
#  'pemba',
#  'hurghada',
#  'east london',
#  'tuktoyaktuk',
#  'provideniya',
#  'thompson',
#  'farafangana',
#  'saskylakh',
#  'arraial do cabo',
#  'tidore',
#  'esperance',
#  'khilok',
#  'bluff',
#  'mayo',
#  'saint-georges',
#  'coihaique',
#  'yuancheng',
#  'lavrentiya',
#  'mahebourg',
#  'hambantota',
#  'narsaq',
#  'bandon',
#  'manadhoo',
#  'fukue',
#  'san quintin',
#  'la ronge',
#  'chuy',
#  'faanui',
#  'opuwo',
#  'hithadhoo',
#  'bernay',
#  'weligama',
#  'eunice',
#  'vaitupu',
#  'hofn',
#  'batsfjord',
#  'cayenne',
#  'cape town',
#  'sakakah',
#  'tasiilaq',
#  'haines junction',
#  'attawapiskat',
#  'bethel',
#  'ust-kuyga',
#  'vagur',
#  'santa isabel',
#  'weatherford',
#  'ushuaia',
#  'clyde river',
#  'pevek',
#  'bredasdorp',
#  'mehamn',
#  'mount isa',
#  'upernavik',
#  'touros',
#  'iskateley',
#  'umzimvubu',
#  'christchurch',
#  'vostok',
#  'chara',
#  'malanje',
#  'athabasca',
#  'cherskiy',
#  'hamilton',
#  'nabire',
#  'tavai',
#  'igrim',
#  'hit',
#  'aykhal',
#  'port hedland',
#  'pisco',
#  'ponta do sol',
#  'aurora',
#  'takoradi',
#  'puerto ayora',
#  'penarroya-pueblonuevo',
#  'okhotsk',
#  'sola',
#  'yellowknife',
#  'tocopilla',
#  'tawkar',
#  'uruzgan',
#  'wagga wagga',
#  'rock sound',
#  'iqaluit',
#  'vaini',
#  'pitimbu',
#  'port alfred',
#  'aparecida',
#  'barrow',
#  'saint-joseph',
#  'marathopolis',
#  'zhezkazgan',
#  'mitsamiouli',
#  'ribeira grande',
#  'kaputa',
#  'amderma',
#  'letka',
#  'mantua',
#  'hervey bay',
#  'hilo',
#  'sibolga',
#  'eydhafushi',
#  'parrita',
#  'bambous virieux',
#  'bani walid',
#  'ambilobe',
#  'new norfolk',
#  'laje',
#  'nazilli',
#  'ventspils',
#  'cam ranh',
#  'muros',
#  'wilmington',
#  'chino valley',
#  'liepaja',
#  'salmas',
#  'bilibino',
#  'vieux-habitants',
#  'tahoua',
#  'puerto colombia',
#  'cidreira',
#  'altay',
#  'codrington',
#  'manzanillo',
#  'cabedelo',
#  'shelekhov',
#  'georgetown',
#  'manta',
#  'torbay',
#  'hokitika',
#  'mount gambier',
#  'portland',
#  'ostersund',
#  'kalmunai',
#  'pafos',
#  'bakchar',
#  'lakhimpur',
#  'houma',
#  'saint-philippe',
#  'bjerkvik',
#  'egvekinot',
#  'achi',
#  'sri aman',
#  'barawe',
#  'scarborough',
#  'paragominas',
#  'luanda',
#  'ancud',
#  'kununurra',
#  'mys shmidta',
#  'illoqqortoormiut',
#  'hermanus',
#  'san cristobal',
#  'siguiri',
#  'aksarka',
#  'khatanga',
#  'shellbrook',
#  'tsihombe',
#  'neyshabur',
#  'aitape',
#  'turukhansk',
#  'pinega',
#  'neyvo-shaytanskiy',
#  'warqla',
#  'geraldton',
#  'royan',
#  'iracoubo',
#  'ocampo',
#  'puerto leguizamo',
#  'senanga',
#  'klaksvik',
#  'barentsburg',
#  'magadi',
#  'nouadhibou',
#  'chokurdakh',
#  'ballina',
#  'souillac',
#  'madimba',
#  'tosya',
#  'hasaki',
#  'castro',
#  'srednekolymsk',
#  'rapu-rapu',
#  'port lincoln',
#  'victoria',
#  'afmadu',
#  'bubaque',
#  'covington',
#  'biloela',
#  'yulara',
#  'necochea',
#  'constitucion',
#  'manzhouli',
#  'port lavaca',
#  'sergiyev posad',
#  'bargal',
#  'port moresby',
#  'taltal',
#  'kirakira',
#  'rio grande',
#  'macusani',
#  'half moon bay',
#  'san patricio',
#  'leshukonskoye',
#  'gushikawa',
#  'tiksi',
#  'kuche',
#  'butaritari',
#  'chagda',
#  'sanchez',
#  'deputatskiy',
#  'lianzhou',
#  'hobyo',
#  'saint george',
#  'khani',
#  'safford',
#  'manado',
#  'airai',
#  'sherman',
#  'buraydah',
#  'taksimo',
#  'paso de carrasco',
#  'margate',
#  'norman wells',
#  'imeni poliny osipenko',
#  'poum',
#  'usinsk',
#  'yima',
#  'paita',
#  'kungurtug',
#  'waingapu',
#  'barraute',
#  'mabaruma',
#  'quelimane',
#  'saint-pierre',
#  'katsuura',
#  'grand river south east',
#  'lata',
#  'fort frances',
#  'samusu',
#  'vila velha',
#  'lompoc',
#  'cabo san lucas',
#  'galveston',
#  'ambon',
#  'yabrud',
#  'bonthe',
#  'khorixas',
#  'labuhan',
#  'anchorage',
#  'gornyak',
#  'beringovskiy',
#  'zaraza',
#  'tuggurt',
#  'veliko gradiste',
#  'mandalgovi',
#  'imperia',
#  'kruisfontein',
#  'benghazi',
#  'pringsewu',
#  'adrar',
#  'port-cartier',
#  'pangnirtung',
#  'baruun-urt',
#  'nikolskoye',
#  'bulgan',
#  'henties bay',
#  'rotnes',
#  'prince rupert',
#  'uige',
#  'bernal',
#  'ixtapa',
#  'mosquera',
#  'boa vista',
#  'goderich',
#  'bengkulu',
#  'monte san pietro',
#  'shache',
#  'coos bay',
#  'hurricane',
#  'vardo',
#  'santa cruz de la palma',
#  'lima',
#  'caravelas',
#  'acajutla',
#  'ambovombe',
#  'atlantic city',
#  'gizo',
#  'innisfail',
#  'kavieng',
#  'luxor',
#  'katherine',
#  'shaoguan',
#  'luquillo',
#  'malwan',
#  'diffa',
#  'yar-sale',
#  'umm lajj',
#  'aswan',
#  'ruteng',
#  'talcahuano',
#  'beysehir',
#  'porto novo',
#  'nanortalik',
#  'pochutla',
#  'sao filipe',
#  'samana',
#  'saleaula',
#  'karwar',
#  'shibukawa',
#  'havre-saint-pierre',
#  'mar del plata',
#  'lagoa',
#  'isangel',
#  'acapulco',
#  'axim',
#  'hay river',
#  'dikson',
#  'nabari',
#  'estacion coahuila',
#  'santa maria',
#  'ormara',
#  'sovetskiy',
#  'banjarmasin',
#  'becerril',
#  'braila',
#  'tutoia',
#  'ostrovnoy',
#  'asau',
#  'fort nelson',
#  'terrace',
#  'hualmay',
#  'rawatsar',
#  'trzebnica',
#  'otane',
#  'rabo de peixe',
#  'manokwari',
#  'seoul',
#  'bjornevatn',
#  'los algarrobos',
#  'safaga',
#  'iaciara',
#  'broome',
#  'beloha',
#  'bandeirantes',
#  'cap malheureux',
#  'severo-kurilsk',
#  'ustka',
#  'rundu',
#  'myitkyina',
#  'rodrigues alves',
#  'vilyuysk',
#  'kahului',
#  'chaykovskaya',
#  'oksfjord',
#  'quatre cocos',
#  'tessalit',
#  'ginda',
#  'college',
#  'bhuj',
#  'komatipoort',
#  'horasan',
#  'owo',
#  'abu samrah',
#  'kano',
#  'tambun',
#  'melo',
#  'malabo',
#  'cooma',
#  'anar darreh',
#  'searcy',
#  'amarpur',
#  'gorno-chuyskiy',
#  'goedereede',
#  'kadaya',
#  'mahajanga',
#  'bulungu',
#  'yablonovo',
#  'bairiki',
#  'kasongo-lunda',
#  'talara',
#  'olafsvik',
#  'evensk',
#  'kurilsk',
#  'mrirt',
#  'el alto',
#  'nahrin',
#  'basoko',
#  'namibe',
#  'martapura',
#  'gannan',
#  'whitehorse',
#  'shingu',
#  'itarema',
#  'alofi',
#  'meulaboh',
#  'north bend',
#  'cuiluan',
#  'katangli',
#  'luderitz',
#  'nelson bay',
#  'marcona',
#  'jaipur hat',
#  'sorland',
#  'troitsk',
#  'dudinka',
#  'disna',
#  'camacari',
#  'bedi',
#  'te anau',
#  'paramirim',
#  'ulladulla',
#  'bria',
#  'ichinoseki',
#  'izmit',
#  'kingston',
#  'cuamba',
#  'guerrero negro',
#  'longyearbyen',
#  'yining',
#  'tumannyy',
#  'puerto escondido',
#  'rathdrum',
#  'wana',
#  'los llanos de aridane',
#  'voh',
#  'palmer',
#  'louisbourg',
#  'luba',
#  'iquique',
#  'lesosibirsk',
#  'atar',
#  'valdivia',
#  'santa rosa',
#  'cilegon',
#  'saint anthony',
#  'fengxian',
#  'ilulissat',
#  'astana',
#  'erzin',
#  'vung tau',
#  'tsabong',
#  'hwange',
#  'saldanha',
#  'chalinze',
#  'werda',
#  'harrison',
#  'linxia',
#  'bhander',
#  'veydelevka',
#  'iringa',
#  'bolshaya sosnova',
#  'xam nua',
#  'petropavlovsk-kamchatskiy',
#  'castro marim',
#  'pombas',
#  'isla mujeres',
#  'tyukhtet',
#  'mhango',
#  'manoel urbano',
#  'ikongo',
#  'galle',
#  'bacolod',
#  'penalva',
#  'taseyevo',
#  'saint-francois',
#  'zyryanovsk',
#  'marsa matruh',
#  'chippewa falls',
#  'bosobolo',
#  'sal rei',
#  'arue',
#  'talnakh',
#  'ugoofaaru',
#  'longavi',
#  'mao',
#  'nouakchott',
#  'sept-iles',
#  'kalemie',
#  'zeya',
#  'san felipe',
#  'bilma',
#  'teya',
#  'katsiveli',
#  'kuryk',
#  'solovetskiy',
#  'yerbogachen',
#  'kismayo',
#  'utiroa',
#  'ondjiva',
#  'gao',
#  'litovko',
#  'upington',
#  'kindu',
#  'chachapoyas',
#  'ewa beach',
#  'kuching',
#  'skjaerhollen',
#  'coquimbo',
#  'sabalgarh',
#  'lufilufi',
#  'markova',
#  'cedeno',
#  'yandoon',
#  'qasigiannguit',
#  'subotica',
#  'bonavista',
#  'maniitsoq',
#  'acarau',
#  'newport',
#  'urumqi',
#  'bartlesville',
#  'satipo',
#  'sonoita',
#  'alta floresta',
#  'olinda',
#  'ijaki',
#  'inverness',
#  'ondangwa',
#  'kidal',
#  'williams lake',
#  'lielvarde',
#  'kaz',
#  'bay roberts',
#  'rehoboth',
#  'north shore',
#  'natal',
#  'pontian kecil',
#  'omboue',
#  'barcelos',
#  'lacombe',
#  'shubarkuduk',
#  'mutsamudu',
#  'gualeguay',
#  'comodoro rivadavia',
#  'tabiauea',
#  'abha',
#  'ayer itam',
#  'pundaguitan',
#  'santa eulalia del rio',
#  'northam',
#  'papetoai',
#  'naraina',
#  'sao felix do xingu',
#  'ocean city',
#  'moron',
#  'sehithwa',
#  'bathsheba',
#  'leh',
#  'saint-augustin',
#  'stirling',
#  'laguna de duero',
#  'kenora',
#  'sabaudia',
#  'lagunas',
#  'providencia',
#  'brae',
#  'olinala',
#  'krasnoyarsk-45',
#  'nome',
#  'gat',
#  'puerto lempira',
#  'buala',
#  'dwarka',
#  'cervo',
#  'misasi',
#  'waipawa',
#  'nadym',
#  'ayutla',
#  'lovozero',
#  'trelleborg',
#  'leningradskiy',
#  'balabac',
#  'yaan',
#  'ondorhaan',
#  'akyab',
#  'koforidua',
#  'plainview',
#  'karlskrona',
#  'aasiaat',
#  'vieste']

# %%
#  Perform API Calls
#      Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"                                      # alternative is "metric"

#      Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#      Set up lists to hold reponse info
CityName = []
CityID = []
Cloudiness = []
CountryCd = []
Date = []
Humidity = []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []

#       Perform a weather check on each city using a series of successive API calls.

# Loop through the list of cities and perform a request for data on each
# Model for weather:
#   Current weather object for Paris: 
#        {'coord': {'lon': 2.35, 'lat': 48.86}, 
#         'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 
#         'base': 'stations', 
#         'main': {'temp': 1.14, 'pressure': 1021, 'humidity': 80, 'temp_min': 1, 'temp_max': 2}, 
#         'visibility': 5000, 
#         'wind': {'speed': 3.6, 'deg': 20}, 
#         'clouds': {'all': 0}, 
#         'dt': 1519248600, 
#         'sys': {'type': 1, 'id': 5610, 'message': 0.0054, 'country': 'FR', 'sunrise': 1519195590, 'sunset': 1519233747}, 
#         'id': 2988507, 
#         'name': 'Paris', 
#         'cod': 200}.

for city in cities:
    response = requests.get(query_url + city).json()
#    pprint (response)  
    
    # Try to grab City info available in the Weather API
    try:
        CityName.append(response['name'])
        CityID.append(response['id'])
        Cloudiness.append(response['clouds']['all'])   
        CountryCd.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lng.append(response['coord']['lon'])
        MaxTemp.append(response['main']['temp_max'])
        WindSpeed.append(response['wind']['speed'])

        #       Include a print log of each city as it's being processed (with the city number and city name).
        print (f"City: {response['name']} and CityID: {response['id']}")
    
    # Handle exceptions for a City that is not available in the Weather API
    except:
        print (f"------City: {city} is not found in the Weather API - return code: {response['cod']}")
        pass
# Out:
# City: Kapaa and CityID: 5848280
# City: Busselton and CityID: 2075265
# City: Atuona and CityID: 4020109
# ------City: sentyabrskiy is not found in the Weather API - return code: 404
# ------City: nizhneyansk is not found in the Weather API - return code: 404
# City: Mercedes and CityID: 3430708
# City: Pozo Colorado and CityID: 3437443
# City: Albany and CityID: 5106841
# City: Kropotkin and CityID: 540761
# City: Hobart and CityID: 2163355
# City: Lebu and CityID: 3883457
# ------City: taolanaro is not found in the Weather API - return code: 404
# City: Saint Paul Harbor and CityID: 5866583
# City: San Carlos del Zulia and CityID: 3628489
# City: Carnarvon and CityID: 2074865
# City: Dingle and CityID: 1714733
# City: Punta Arenas and CityID: 3874787
# City: Jamestown and CityID: 5122534
# City: Pouembout and CityID: 2138592
# City: Ganzhou and CityID: 1810637
# City: Laguna and CityID: 5364271
# City: Sitka and CityID: 5557293
# City: Cockburn Town and CityID: 3576994
# City: Qaanaaq and CityID: 3831208
# ------City: belushya guba is not found in the Weather API - return code: 404
# City: Port Elizabeth and CityID: 964420
# City: Salalah and CityID: 286621
# City: Kaitangata and CityID: 2208248
# City: Berlevåg and CityID: 780687
# City: Mataura and CityID: 6201424
# City: Husavik and CityID: 2629833
# City: Fortuna and CityID: 5563839
# City: Tuatapere and CityID: 2180815
# City: Avarua and CityID: 4035715
# City: Vila Franca do Campo and CityID: 3372472
# City: Rikitea and CityID: 4030556
# City: Pemba and CityID: 1028918
# City: Hurghada and CityID: 361291
# City: East London and CityID: 1006984
# City: Tuktoyaktuk and CityID: 6170031
# City: Provideniya and CityID: 4031574
# City: Thompson and CityID: 6165406
# City: Farafangana and CityID: 1065158
# City: Saskylakh and CityID: 2017155
# City: Arraial do Cabo and CityID: 3471451
# ------City: tidore is not found in the Weather API - return code: 404
# City: Esperance and CityID: 2071860
# City: Khilok and CityID: 2022463
# City: Bluff and CityID: 2206939
# City: Mayo and CityID: 4362001
# City: St. George's and CityID: 3579925
# City: Coyhaique and CityID: 3894426
# City: Yuancheng and CityID: 1786110
# City: Lavrentiya and CityID: 4031637
# City: Mahébourg and CityID: 934322
# City: Hambantota and CityID: 1244926
# City: Narsaq and CityID: 3421719
# City: Bandon and CityID: 2966370
# City: Manadhoo and CityID: 1337618
# City: Kaz and CityID: 1504081
# City: Bay Roberts and CityID: 5895424
# City: Rehoboth and CityID: 3353540
# City: North Shore and CityID: 2185964
# City: Natal and CityID: 3394023
# City: Pontian Kecil and CityID: 1732711
# City: Omboué and CityID: 2396853
# City: Barcelos and CityID: 2742416
# City: Lacombe and CityID: 6035615
# City: Shubarkuduk and CityID: 608271
# ------City: mutsamudu is not found in the Weather API - return code: 404
# City: Gualeguay and CityID: 3433663
# City: Comodoro Rivadavia and CityID: 3860443
# ------City: tabiauea is not found in the Weather API - return code: 404
# City: Abhā and CityID: 110690
# ------City: ayer itam is not found in the Weather API - return code: 404
# City: Pundaguitan and CityID: 1698289
# ------City: santa eulalia del rio is not found in the Weather API - return code: 404
# City: Northam and CityID: 2641434
# City: Papetoai and CityID: 4033910
# City: Naraina and CityID: 1261872
# City: São Félix do Xingu and CityID: 3388847
# City: Ocean City and CityID: 4503351
# City: Morón and CityID: 3430545
# City: Sehithwa and CityID: 933109
# City: Bathsheba and CityID: 3374083
# City: Leh and CityID: 1264976
# City: Saint-Augustin and CityID: 6137462
# City: Stirling and CityID: 2636910
# City: Laguna de Duero and CityID: 3119631
# City: Kenora and CityID: 5991056
# City: Sabaudia and CityID: 3168764
# City: Lagunas and CityID: 3695844
# City: La Providencia and CityID: 3991622
# City: Brae and CityID: 2654970
# City: Olinalá and CityID: 3522364
# ------City: krasnoyarsk-45 is not found in the Weather API - return code: 404
# City: Nome and CityID: 5870133
# City: Kiryat Gat and CityID: 293842
# City: Puerto Lempira and CityID: 3603157
# City: Buala and CityID: 2109528
# City: Dwārka and CityID: 1272140
# City: Cervo and CityID: 3125287
# City: Misasi and CityID: 153772
# City: Waipawa and CityID: 2206874
# City: Nadym and CityID: 1498087
# City: Ayutla and CityID: 4017924
# City: Lovozero and CityID: 533933
# City: Trelleborg and CityID: 2667402
# City: Leningradskiy and CityID: 2123814
# City: Balabac and CityID: 1728675
# City: Yaan and CityID: 2338660
# ------City: ondorhaan is not found in the Weather API - return code: 404
# City: Sittwe and CityID: 1295765
# City: Koforidua and CityID: 2299522
# City: Plainview and CityID: 5131638
# City: Karlskrona and CityID: 2701713
# City: Aasiaat and CityID: 3424901
# City: Vieste and CityID: 3164387

# %%
#-----------------------------
#Data Retrieval Complete      
#-----------------------------
# Convert Raw Data to DataFrame
weather_dict = {
    "CityName": CityName,
    "CityID": CityID,
    "Cloudiness": Cloudiness,
    "CountryCd": CountryCd,
    "Date": Date,
    "Humidity": Humidity,
    "Lat": Lat,
    "Lng": Lng,
    "MaxTemp": MaxTemp,
    "WindSpeed": WindSpeed
    }
# create a data frame from City,CityID,Cloudiness,CountryCd,Date,Humidity,lat,Lng,MaxTemp,WindSpeed
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#           CityName   CityID  Cloudiness CountryCd        Date  Humidity  \
# 0            Kapaa  5848280          75        US  1584061482        83
# 1        Busselton  2075265          24        AU  1584061271        73
# 2           Atuona  4020109          40        PF  1584061555        74
# 3         Mercedes  3430708           0        AR  1584061508        81
# 4    Pozo Colorado  3437443          45        PY  1584061556        34
# ..             ...      ...         ...       ...         ...       ...
# 567      Koforidua  2299522          75        GH  1584061689        89
# 568      Plainview  5131638          90        US  1584061690        93
# 569     Karlskrona  2701713          27        SE  1584061690        86
# 570        Aasiaat  3424901          14        GL  1584061690        97
# 571         Vieste  3164387          40        IT  1584061690        93
#
#        Lat     Lng  MaxTemp  WindSpeed
# 0    22.08 -159.32    77.00      11.41
# 1   -33.65  115.33    66.99       3.00
# 2    -9.80 -139.03    82.29       8.75
# 3   -34.65  -59.43    73.99       9.31
# 4   -23.49  -58.80    85.51       1.90
# ..     ...     ...      ...        ...
# 567   6.09   -0.26    84.20      11.41
# 568  40.78  -73.47    46.99      14.99
# 569  56.16   15.59    39.20      10.29
# 570  68.71  -52.87    -6.77       4.09
# 571  41.88   16.18    57.00      11.41
#
# [572 rows x 10 columns]

# %%
#Export the city data into a .csv.   "../output_data/cities.csv"
# Save the updated dataframe as a csv
weather_data.to_csv("output_data/cities.csv", encoding="utf-8", index=False)
 
#Display the DataFrame        ---How to format date (unix dt) https://momentjs.com/---
weather_data.head()
# Out:
#         CityName   CityID  Cloudiness CountryCd        Date  Humidity    Lat  \
# 0          Kapaa  5848280          75        US  1584061482        83  22.08
# 1      Busselton  2075265          24        AU  1584061271        73 -33.65
# 2         Atuona  4020109          40        PF  1584061555        74  -9.80
# 3       Mercedes  3430708           0        AR  1584061508        81 -34.65
# 4  Pozo Colorado  3437443          45        PY  1584061556        34 -23.49
#
#       Lng  MaxTemp  WindSpeed
# 0 -159.32    77.00      11.41
# 1  115.33    66.99       3.00
# 2 -139.03    82.29       8.75
# 3  -59.43    73.99       9.31
# 4  -58.80    85.51       1.90

# %%
# Plotting the Data

#      Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#      Save the plotted figures as .pngs.

#      After each plot add a sentence or too explaining what the code is and analyzing. 
#      Your first objective is to build a series of scatter plots to showcase the following relationships:

# %%
# * Temperature (F) vs. Latitude
plt.scatter(weather_data["MaxTemp"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Max Temperature vs Latitude for World Cities Mar/2020")
plt.xlabel("Temperature (F)")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("MaxTempVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The further a world city is located from the equator, as defined by their latitude (both north & south / positive & negative) 
#         their maximum temperature exhibits colder temperatures, and the closer to the equator, the warmer the temperatures.

# %%
# * Humidity (%) vs. Latitude
plt.scatter(weather_data["Humidity"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Humidity vs Latitude for World Cities Mar/2020")
plt.xlabel("Humidity")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# Humidity has the greatest variance in the Middle latitudes. Humidity at the highest levels 
#           is concentrated from south 40 degrees to north 75 degrees.

# %%
# * Cloudiness (%) vs. Latitude
plt.scatter(weather_data["Cloudiness"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Cloudiness vs Latitude for World Cities Mar/2020")
plt.xlabel("Cloudiness")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The relative cloudiness seems disbursed across the earth.

# %%
# * Wind Speed (mph) vs. Latitude
plt.scatter(weather_data["WindSpeed"], weather_data["Lat"], marker="o")
# Incorporate the graph properties
plt.title("Wind Speed vs Latitude for World Cities Mar/2020")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedVsLatForWorldCities.png")

# Show plot
plt.show()

# %%
# The greatest wind speed variance occurs in the middle latitudes (25-65mph in the North and 20-45mph in the South) ).

# %%
# Your next objective is to run linear regression on each relationship, only this time separating them into 
#                      Northern Hemisphere (greater than or equal to 0 degrees latitude)        
#                      and Southern Hemisphere (less than 0 degrees latitude):

# %%
# After each pair of plots explain what the linear regression is modelling such as any relationships you notice 
#                      and any other analysis you may have.

# %%
NorthernWeather_df = weather_data.loc[weather_data['Lat'] >= 0]
SouthernWeather_df = weather_data.loc[weather_data['Lat'] < 0]

# %%
#* Northern Hemisphere - Temperature (F) vs. Latitude

# Make the Regression Parameters  -North                                                               x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(NorthernWeather_df['MaxTemp'], NorthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_NrthTemp = slope * NorthernWeather_df['MaxTemp'] + intercept
# Create the Line Equation
LineEq_NrthTemp = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=-0.6282143447306326 Intercept=68.28801656541097 Rvalue=-0.86771448306809 Pvalue=5.023760795684843e-118 Stderr=0.018412413252745886

# %%
# * Northern Temperature (F) vs. Latitude
plt.scatter(NorthernWeather_df["MaxTemp"], NorthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(NorthernWeather_df['MaxTemp'], regress_NrthTemp, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_NrthTemp, xy = (40, 70), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Max Temperature vs Latitude Regression North Latitude World Cities Mar/2020")
plt.xlabel("Temperature (F)")
plt.ylabel("Northern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("MaxTempVsLatForNorthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is -0.87.

# %%
#

# %%
#* Southern Hemisphere - Temperature (F) vs. Latitude

# Make the Regression Parameters   -South                                                              x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(SouthernWeather_df['MaxTemp'], SouthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_SothTemp = slope * SouthernWeather_df['MaxTemp'] + intercept
# Create the Line Equation
LineEq_SothTemp = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.7092539034184614 Intercept=-72.40464153214735 Rvalue=0.484408587648703 Pvalue=1.8752160299424626e-12 Stderr=0.0939210621696198

# %%
# * Southern Temperature (F) vs. Latitude
plt.scatter(SouthernWeather_df["MaxTemp"], SouthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(SouthernWeather_df['MaxTemp'], regress_SothTemp, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_SothTemp, xy = (70, -50), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Max Temperature vs Latitude Regression South Latitude World Cities Mar/2020")
plt.xlabel("Temperature (F)")
plt.ylabel("Southern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("MaxTempVsLatForSouthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.48.

# %%
#* Northern Hemisphere - Humidity (%) vs. Latitude
# Make the Regression Parameters  -North                                                               x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(NorthernWeather_df['Humidity'], NorthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_NrthHum = slope * NorthernWeather_df['Humidity'] + intercept
# Create the Line Equation
LineEq_NrthHum = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.18754209873613967 Intercept=25.29860380646953 Rvalue=0.1871395303319674 Pvalue=0.0002261595453997231 Stderr=0.05036866502222037

# %%
# * Northern Humidity (%) vs. Latitude
plt.scatter(NorthernWeather_df["Humidity"], NorthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(NorthernWeather_df['Humidity'], regress_NrthHum, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_NrthHum, xy = (10, 70), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Humidity vs Latitude Regression North Latitude World Cities Mar/2020")
plt.xlabel("Humidity (%)")
plt.ylabel("Northern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("HumidityVsLatForNorthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.19.

# %%
#* Southern Hemisphere - Humidity (%) vs. Latitude
# Make the Regression Parameters   -South                                                              x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(SouthernWeather_df['Humidity'], SouthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_SothHum = slope * SouthernWeather_df['Humidity'] + intercept
# Create the Line Equation
LineEq_SothHum = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.17489382616087448 Intercept=-33.90675813021535 Rvalue=0.2239384109208696 Pvalue=0.002006005145752218 Stderr=0.05581067708307184

# %%
# * Southern Humidity (%) vs. Latitude
plt.scatter(SouthernWeather_df["Humidity"], SouthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(SouthernWeather_df['Humidity'], regress_SothHum, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_SothHum, xy = (10, -10), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Humidity vs Latitude Regression South Latitude World Cities Mar/2020")
plt.xlabel("Humidity (%)")
plt.ylabel("Southern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("HumidityVsLatForSouthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.22.

# %%
#* Northern Hemisphere - Cloudiness (%) vs. Latitude
# Make the Regression Parameters  -North                                                               x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(NorthernWeather_df['Cloudiness'], NorthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_NrthCloud = slope * NorthernWeather_df['Cloudiness'] + intercept
# Create the Line Equation
LineEq_NrthCloud = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.18884558071958651 Intercept=28.43263114478787 Rvalue=0.34693379389323276 Pvalue=2.6572462506621497e-12 Stderr=0.026120426835607006

# %%
# * Northern Cloudiness (%) vs. Latitude
plt.scatter(NorthernWeather_df["Cloudiness"], NorthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(NorthernWeather_df['Cloudiness'], regress_NrthCloud, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_NrthCloud, xy = (40, 75), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Cloudiness vs Latitude Regression North Latitude World Cities Mar/2020")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Northern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("CloudinessVsLatForNorthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.35.

# %%
#* Southern Hemisphere - Cloudiness (%) vs. Latitude
# Make the Regression Parameters   -South                                                              x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(SouthernWeather_df['Cloudiness'], SouthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_SothCloud = slope * SouthernWeather_df['Cloudiness'] + intercept
# Create the Line Equation
LineEq_SothCloud = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.11844582725477355 Intercept=-27.012144552835753 Rvalue=0.3123594225718193 Pvalue=1.2771321988817353e-05 Stderr=0.026412884188311468

# %%
# * Southern Cloudiness (%) vs. Latitude
plt.scatter(SouthernWeather_df["Cloudiness"], SouthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(SouthernWeather_df['Cloudiness'], regress_SothCloud, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_SothCloud, xy = (0, -55), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Cloudiness vs Latitude Regression South Latitude World Cities Mar/2020")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Southern Hemisphere Latitude")
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("CloudinessVsLatForSouthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.31.

# %%
#* Northern Hemisphere - Wind Speed (mph) vs. Latitude
# Make the Regression Parameters  -North                                                               x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(NorthernWeather_df['WindSpeed'], NorthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_NrthWind = slope * NorthernWeather_df['WindSpeed'] + intercept
# Create the Line Equation
LineEq_NrthWind = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=0.8444803118269246 Intercept=30.563346561715033 Rvalue=0.29695799244710974 Pvalue=2.9457960887412744e-09 Stderr=0.13893652152899696

# %%
# * Northern Wind Speed (mph)) vs. Latitude
plt.scatter(NorthernWeather_df["WindSpeed"], NorthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(NorthernWeather_df['WindSpeed'], regress_NrthWind, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_NrthWind, xy = (30, 70), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Wind Speed vs Latitude Regression North Latitude World Cities Mar/2020")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Northern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("WindSpeedVsLatForNorthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is 0.3.

# %%
#* Southern Hemisphere - Wind Speed (mph) vs. Latitude
# Make the Regression Parameters   -South                                                              x                                 y
(slope, intercept, rvalue, pvalue, stderr) = linregress(SouthernWeather_df['WindSpeed'], SouthernWeather_df['Lat'])
print (f"Slope={slope} Intercept={intercept} Rvalue={rvalue} Pvalue={pvalue} Stderr={stderr}")
# Calculate the Regress Values
regress_SothWind = slope * SouthernWeather_df['WindSpeed'] + intercept
# Create the Line Equation
LineEq_SothWind = "y= " + str(round(slope,0)) + "x+ " + str(round(intercept,0))
# Out:
# Slope=-0.5726589214502669 Intercept=-16.21026767089638 Rvalue=-0.21678541960263936 Pvalue=0.00280620498078899 Stderr=0.1890849094353878

# %%
# * Southern Wind Speed (mph) vs. Latitude
plt.scatter(SouthernWeather_df["WindSpeed"], SouthernWeather_df["Lat"], marker="o")
# Plot the Regress Values
plt.plot(SouthernWeather_df['WindSpeed'], regress_SothWind, c = "red")
# Annotate the Line Equation
plt.annotate(LineEq_SothWind, xy = (10, -55), fontsize = 15, color = "red")
# Create the Labels
# Incorporate the graph properties
plt.title("Wind Speed vs Latitude Regression South Latitude World Cities Mar/2020")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Southern Hemisphere Latitude")
plt.grid(True)
# Display the R squared Value
print(f"The R-squared value is {round(rvalue,2)}.")
# Save the figure
plt.savefig("WindSpeedVsLatForSouthWorldCities.png")

# Show plot
plt.show()
# Out:
# The R-squared value is -0.22.
